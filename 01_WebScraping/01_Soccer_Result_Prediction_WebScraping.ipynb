# %% [markdown]
# # Soccer Analytics -  Predicting Soccer Match Results to Improve Chances of Winning Bets

# %% [markdown]
# ## Objective
# - __To webscrape metrics and features related to match, player and teams.__<br>
# - __Transform the aggregated data into a training dataset using functional knowledge and machine learning algorithms.__<br>
# - __Build prediction models on the training data and predict the results for current season 2018-2019.__<br>
# - __Compare the predictions with predictions from betting websites and football fanatics to check the effectiveness of the model built and where it stands.__<br>

# %% [markdown]
# This Jupyter file consists of 4 major webscrape codes - Match level data, Player metrics summary, Scoreboard data and Team Metrics data at season level

# %% [markdown]
# ## 01- WebScraping
# __Used Beautiful Soup python package to scrape soccer related data__<br>
# __Dataset Source__:<br>
# Understat - [Understat.com](https://understat.com/)<br><br>

# %% [markdown]
# ### A. Scrape EPL Match Statistics  for five seasons - 2014 to 2018

# %%
import requests, bs4, os
import numpy as np
import pandas as pd

# %% [markdown]
# Change values of k -> 2014,2015,2016,2017,2018 to scrape each season individual match stats

# %%
import requests, bs4, os
import json
import numpy as np
import pandas as pd

scrblink ="https://understat.com/league/EPL/"
k=2018
player_perf=pd.DataFrame()
final=pd.DataFrame()
res = requests.get(scrblink+str(k))
res.raise_for_status()
soup = bs4.BeautifulSoup(res.text)
print('Web Scrape - Get Final Team and Player Scoreboard from Understat.com')
## Team Final Scoreboard JSON Data
matches = soup.find_all('script')
mat2=matches[1].text.strip()
mat3 =mat2.encode('utf8').decode('unicode_escape')
ma= mat3.find("'")
md =mat3.find(")")
matstr = mat3[ma+1:md-1]
match = json.loads(matstr)
page=list()
for k in range(0,len(match)):
    page.append(match[k]['id'])
link ="https://understat.com/match/"
final_df=pd.DataFrame()

try:
    for k in range(0,len(page)):
        res = requests.get(link+str(page[k]))
        res.raise_for_status()
        soup = bs4.BeautifulSoup(res.text)
        print('Web Scrape - Get Team Performance Metrics from Understat.com')
        ## Match Details
        titles = soup.find_all('title')
        ## Match Stats
        home_team = soup.find_all('div', attrs={'class':'progress-home'})
        away_team = soup.find_all('div', attrs={'class':'progress-away'})
        draw_chance= soup.find_all('div', attrs={'class':'progress-draw'})
        print('Web Scraping - Completed')
        homefeat=[]
        awayfeat=[]
        drawfeat=[]
        for i in range(0,len(home_team)):
            a= home_team[i].text.strip()
            if (a==''):
                homefeat.append(home_team[i]['title'])
            else:
                homefeat.append(a)
        for i in range(0,len(away_team)):
            a= away_team[i].text.strip()
            if (a==''):
                awayfeat.append(away_team[i]['title'])
            else:
                awayfeat.append(a)
        for i in range(0,len(draw_chance)):
            a= draw_chance[i].text.strip()
            if (a==''):
                drawfeat.append(draw_chance[i]['title'])
            else:
                drawfeat.append(a)
        c = pd.DataFrame(np.hstack((homefeat,awayfeat)))
        soccer_df = c.transpose()
        soccer_df['Dchance']=drawfeat
        soccer_df.rename(columns = {0:'Hteam',1:'Hchance',2:'Hgoals',3:'HxG',4:'Hshots',5:'Hshotstrgt',6:'Hdeep',7:'Hppda',8:'Hxpts',9:'Ateam',10:'Achance',11:'Agoals',12:'AxG',13:'Ashots',14:'Ashotstrgt',15:'Adeep',16:'Appda',17:'Axpts'},inplace=True)
        ftr=[]
        for i in range(0,len(soccer_df.index)):
            if (soccer_df['Hgoals'][i]>soccer_df['Agoals'][i]):
                ftr.append(soccer_df['Hteam'][i])
            elif(soccer_df['Hgoals'][i]<soccer_df['Agoals'][i]):
                ftr.append(soccer_df['Ateam'][i])
            else:
                ftr.append('Draw')
        soccer_df['FTR']=ftr
        soccer_df['Season']=titles[0].text.split('|')[2]
        soccer_df['League']=titles[0].text.split('|')[1]
        soccer_df['Description']=titles[0].text.split('|')[0]
        date_str = titles[0].text.split('|')[0].split('(')[1]
        frmt_date =date_str.strip()[:17]
        frmt_date
        soccer_df['MatchDate']=frmt_date
        final_df = pd.concat([final_df, soccer_df])
        print("All "+str(k)+"th match details obtained")
except Exception:
    pass
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Web Scrape - Get Final Team and Player Scoreboard from Understat.com
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 0th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 1th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 2th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 3th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 4th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 5th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 6th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 7th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 8th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 9th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 10th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 11th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 12th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 13th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 14th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 15th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 16th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 17th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 18th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 19th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 20th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 21th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 22th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 23th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 24th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 25th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 26th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 27th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 28th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 29th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 30th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 31th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 32th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 33th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 34th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 35th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 36th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 37th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 38th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 39th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 40th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 41th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 42th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 43th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 44th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 45th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 46th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 47th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 48th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 49th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 50th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 51th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 52th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 53th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 54th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 55th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 56th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 57th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 58th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 59th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 60th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 61th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 62th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 63th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 64th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 65th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 66th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 67th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 68th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 69th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 70th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 71th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 72th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 73th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 74th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 75th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 76th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 77th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 78th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 79th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 80th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 81th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 82th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 83th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 84th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 85th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 86th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 87th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 88th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 89th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 90th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 91th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 92th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 93th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 94th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 95th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 96th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 97th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 98th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 99th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 100th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 101th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 102th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 103th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 104th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 105th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 106th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 107th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 108th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 109th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 110th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 111th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 112th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 113th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 114th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 115th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 116th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 117th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 118th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 119th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 120th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 121th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 122th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 123th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 124th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 125th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 126th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 127th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 128th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 129th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 130th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 131th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 132th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 133th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 134th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 135th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 136th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 137th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 138th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 139th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 140th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 141th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 142th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 143th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 144th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 145th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 146th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 147th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 148th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 149th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 150th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 151th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 152th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 153th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 154th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 155th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 156th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 157th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 158th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 159th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 160th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 161th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 162th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 163th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 164th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 165th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 166th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 167th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 168th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 169th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 170th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 171th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 172th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 173th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 174th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 175th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 176th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 177th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 178th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 179th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 180th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 181th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 182th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 183th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 184th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 185th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 186th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 187th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 188th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 189th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 190th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 191th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 192th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 193th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 194th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 195th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 196th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 197th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 198th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 199th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 200th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 201th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 202th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 203th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 204th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 205th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 206th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 207th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 208th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 209th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 210th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 211th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 212th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 213th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 214th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 215th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 216th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 217th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 218th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 219th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 220th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 221th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 222th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 223th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 224th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 225th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 226th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 227th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 228th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 229th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 230th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 231th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 232th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 233th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 234th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 235th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 236th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 237th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 238th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 239th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 240th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 241th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 242th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 243th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 244th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 245th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 246th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 247th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 248th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 249th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 250th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 251th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 252th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 253th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 254th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 255th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 256th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 257th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 258th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 259th match details obtained
# Web Scrape - Get Team Performance Metrics from Understat.com
# Web Scraping - Completed
# All 260th match details obtained

# %%
len(page) ## There are 380 matches played in one complete season
# Out:
# 380

# %%
final_df.to_csv('soccer_data.csv')
final_df
# Out:
#                       Hteam Hchance Hgoals   HxG Hshots Hshotstrgt Hdeep  \
# 0         Manchester United     28%      2  1.51      8          6     3
# 0          Newcastle United      8%      1  0.97     15          2     8
# 0                   Watford     64%      2  1.42     19          5     8
# 0              Huddersfield      2%      0  0.40      6          1     2
# 0                    Fulham     20%      0  0.64     15          6     3
# 0               Bournemouth     68%      2  2.60     12          4    12
# 0   Wolverhampton Wanderers     36%      2  0.89     11          4     4
# 0               Southampton     26%      0  1.02     18          3     3
# 0                 Liverpool     99%      4  4.34     18          8    16
# 0                   Arsenal      5%      0  0.45      9          3     8
# 0                   Cardiff     24%      0  1.16     12          1     3
# 0                  West Ham     20%      1  1.10     11          5     9
# 0                 Tottenham     78%      3  3.27     25         11    20
# 0                 Leicester      6%      2  0.22      6          2     4
# 0                   Everton     43%      2  2.02     13          7     4
# 0                   Chelsea     23%      3  1.72     24         11    10
# 0           Manchester City     98%      6  4.60     32         14    17
# 0                   Burnley      3%      1  0.39      8          3     4
# 0                  Brighton     35%      3  1.64      6          3     2
# 0            Crystal Palace      1%      0  0.37      8          2     3
# 0   Wolverhampton Wanderers     22%      1  1.26     11          2     2
# 0               Southampton     28%      1  0.54     12          5     7
# 0              Huddersfield      6%      0  0.20      5          1     1
# 0                    Fulham     45%      4  1.92     25         12    10
# 0               Bournemouth     88%      2  2.59     17          5    11
# 0                   Arsenal     53%      3  1.79     17         10     8
# 0                 Liverpool     71%      1  1.81     22          8    13
# 0                   Watford     32%      2  1.15     13          5     7
# 0          Newcastle United      3%      1  0.21      6          2     3
# 0         Manchester United     27%      0  1.40     23          5     7
# ..                      ...     ...    ...   ...    ...        ...   ...
# 0              Huddersfield     21%      0  0.74     10          2     2
# 0                    Fulham     61%      4  3.30     24          7     6
# 0                   Arsenal     87%      2  2.67     15          4    20
# 0         Manchester United     83%      2  2.87     28          9    15
# 0          Newcastle United     23%      2  0.96      6          2     2
# 0               Bournemouth     75%      4  2.15     12          7    11
# 0               Southampton     46%      1  1.33     13          4     6
# 0                 Tottenham     55%      2  1.36     17          3    10
# 0                 Liverpool     15%      1  0.55     10          3    12
# 0                 Tottenham     95%      1  3.19     21          4    12
# 0                   Everton     24%      1  1.33     13          4     7
# 0            Crystal Palace     84%      2  2.21     17          6     6
# 0                   Chelsea     96%      5  3.21     23          7    19
# 0                   Burnley     72%      1  2.04     15          6     9
# 0                  Brighton     85%      0  2.18     21          4     8
# 0                   Cardiff     92%      2  2.54     12          5     5
# 0                 Leicester     44%      0  1.75     17          6     8
# 0           Manchester City     93%      3  2.91     19         12    22
# 0                  West Ham     23%      1  0.79     13          2     6
# 0                   Everton      0%      0  0.11      4          1     4
# 0                    Fulham     39%      0  2.18     15          3     4
# 0            Crystal Palace     55%      1  2.47     25          5    19
# 0                   Watford     66%      1  1.53      7          2     6
# 0               Southampton     76%      1  1.64     14          7     6
# 0                 Liverpool     87%      3  2.53     20          9    17
# 0              Huddersfield     27%      1  1.16     15          6     6
# 0                  Brighton     22%      1  1.27     16          6     9
# 0                 Tottenham      9%      3  1.21     12          5     5
# 0           Manchester City     94%      6  4.04     15          9    11
# 0   Wolverhampton Wanderers     86%      1  2.31     22          6     6
#
#     Hppda Hxpts                    Ateam        ...         Ashotstrgt Adeep  \
# 0            Arsenal 2 - 1 Cardiff (January 29 2019)    January 29 2019)
# 0   Manchester United 2 - 2 Burnley (January 29 20...   January 29 2019)
# 0   Newcastle United 2 - 1 Manchester City (Januar...   January 29 2019)
# 0        Bournemouth 4 - 0 Chelsea (January 30 2019)    January 30 2019)
# 0   Southampton 1 - 1 Crystal Palace (January 30 2...   January 30 2019)
# 0          Tottenham 2 - 1 Watford (January 30 2019)    January 30 2019)
# 0        Liverpool 1 - 1 Leicester (January 30 2019)    January 30 2019)
# 0   Tottenham 1 - 0 Newcastle United (February 02 ...  February 02 2019)
# 0   Everton 1 - 3 Wolverhampton Wanderers (Februar...  February 02 2019)
# 0     Crystal Palace 2 - 0 Fulham (February 02 2019)   February 02 2019)
# 0      Chelsea 5 - 0 Huddersfield (February 02 2019)   February 02 2019)
# 0       Burnley 1 - 1 Southampton (February 02 2019)   February 02 2019)
# 0          Brighton 0 - 0 Watford (February 02 2019)   February 02 2019)
# 0       Cardiff 2 - 0 Bournemouth (February 02 2019)   February 02 2019)
# 0   Leicester 0 - 1 Manchester United (February 03...  February 03 2019)
# 0   Manchester City 3 - 1 Arsenal (February 03 2019)   February 03 2019)
# 0        West Ham 1 - 1 Liverpool (February 04 2019)   February 04 2019)
# 0   Everton 0 - 2 Manchester City (February 06 2019)   February 06 2019)
# 0   Fulham 0 - 3 Manchester United (February 09 20...  February 09 2019)
# 0   Crystal Palace 1 - 1 West Ham (February 09 2019)   February 09 2019)
# 0           Watford 1 - 0 Everton (February 09 2019)   February 09 2019)
# 0       Southampton 1 - 2 Cardiff (February 09 2019)   February 09 2019)
# 0     Liverpool 3 - 0 Bournemouth (February 09 2019)   February 09 2019)
# 0      Huddersfield 1 - 2 Arsenal (February 09 2019)   February 09 2019)
# 0          Brighton 1 - 3 Burnley (February 09 2019)   February 09 2019)
# 0       Tottenham 3 - 1 Leicester (February 10 2019)   February 10 2019)
# 0   Manchester City 6 - 0 Chelsea (February 10 2019)   February 10 2019)
# 0   Wolverhampton Wanderers 1 - 1 Newcastle United...  February 11 2019)
#
# [261 rows x 24 columns]

# %% [markdown]
# #### Data Quality Check - Check for empty fields

# %% [markdown]
# -   __ 2014-15 season check for NA__

# %%
final_df.isna().any()
# Out:
# Hteam          False
# Hchance        False
# Hgoals         False
# HxG            False
# Hshots         False
# Hshotstrgt     False
# Hdeep          False
# Hppda          False
# Hxpts          False
# Ateam          False
# Achance        False
# Agoals         False
# AxG            False
# Ashots         False
# Ashotstrgt     False
# Adeep          False
# Appda          False
# Axpts          False
# Dchance        False
# FTR            False
# Season         False
# League         False
# Description    False
# MatchDate      False
# dtype: bool

# %% [markdown]
# -   __ 2015-16 season check for NA__

# %%
final_df.isna().any()
# Out:
# Hteam          False
# Hchance        False
# Hgoals         False
# HxG            False
# Hshots         False
# Hshotstrgt     False
# Hdeep          False
# Hppda          False
# Hxpts          False
# Ateam          False
# Achance        False
# Agoals         False
# AxG            False
# Ashots         False
# Ashotstrgt     False
# Adeep          False
# Appda          False
# Axpts          False
# Dchance        False
# FTR            False
# Season         False
# League         False
# Description    False
# MatchDate      False
# dtype: bool

# %% [markdown]
# -   __ 2016-17 season check for NA__

# %%
final_df.isna().any()
# Out:
# Hteam          False
# Hchance        False
# Hgoals         False
# HxG            False
# Hshots         False
# Hshotstrgt     False
# Hdeep          False
# Hppda          False
# Hxpts          False
# Ateam          False
# Achance        False
# Agoals         False
# AxG            False
# Ashots         False
# Ashotstrgt     False
# Adeep          False
# Appda          False
# Axpts          False
# Dchance        False
# FTR            False
# Season         False
# League         False
# Description    False
# MatchDate      False
# dtype: bool

# %% [markdown]
# -   __ 2017-18 season check for NA__

# %%
final_df.isna().any()
# Out:
# Hteam          False
# Hchance        False
# Hgoals         False
# HxG            False
# Hshots         False
# Hshotstrgt     False
# Hdeep          False
# Hppda          False
# Hxpts          False
# Ateam          False
# Achance        False
# Agoals         False
# AxG            False
# Ashots         False
# Ashotstrgt     False
# Adeep          False
# Appda          False
# Axpts          False
# Dchance        False
# FTR            False
# Season         False
# League         False
# Description    False
# MatchDate      False
# dtype: bool

# %% [markdown]
# -   __ 2018-19 season check for NA__

# %%
final_df.isna().any()
# Out:
# Hteam          False
# Hchance        False
# Hgoals         False
# HxG            False
# Hshots         False
# Hshotstrgt     False
# Hdeep          False
# Hppda          False
# Hxpts          False
# Ateam          False
# Achance        False
# Agoals         False
# AxG            False
# Ashots         False
# Ashotstrgt     False
# Adeep          False
# Appda          False
# Axpts          False
# Dchance        False
# FTR            False
# Season         False
# League         False
# Description    False
# MatchDate      False
# dtype: bool

# %% [markdown]
# ### B. Scrape EPL Player Summary & Match Statistics  for five seasons - 2014 to 2018

# %%
import requests, bs4, os
import json
import numpy as np
import pandas as pd
link ="https://understat.com/match/"
start=4439
end=4758
player_df=pd.DataFrame()
player_df3=pd.DataFrame()
for k in range(start,end):
    res = requests.get(link+str(k))
    res.raise_for_status()
    soup = bs4.BeautifulSoup(res.text)
    print('Web Scrape - Get Player Performance Metrics per Match from Understat.com')
    ## Player JSON Data
    titles=soup.find('title')
    players = soup.find_all('script')
    date_str = titles.text.split('|')[0].split('(')[1].strip()
    season = titles.text.split('|')[2].strip()
    description=  titles.text.split('|')[0].strip()
    league =  titles.text.split('|')[1].strip()
    v2=players[2].text.strip()
    v3 =v2.encode('utf8').decode('unicode_escape')
    c = v3.find("'")
    d =v3.find(");")
    newstr = v3[c+1:d-1]
    y = json.loads(newstr)
    f1 = list(y.keys())
    final=pd.DataFrame()
    for i in range(0,len(f1)):
        if (f1[i]=='h'):
            home = pd.DataFrame.from_dict(y[f1[i]],orient='index')
            home.reset_index(inplace=True)
            home.drop(columns=['index'],inplace=True)
        if (f1[i]=='a'):
            away = pd.DataFrame.from_dict(y[f1[1]],orient='index')
            away.reset_index(inplace=True)
            away.drop(columns=['index'],inplace=True)
    hcol = home.columns
    hcol_new=[]
    acol = away.columns
    acol_new=[]
    for i in range(0,len(hcol)):
        hcol_new.append('h_'+hcol[i])
    for i in range(0,len(acol)):
        acol_new.append('a_'+acol[i]) 
    total = hcol_new+acol_new
    final=pd.concat([home,away],axis=1)
    final['Season']=season
    final['League']=league
    final['Description']=description
    final['MatchDate']=date_str
    final['MatchID']=k
    player_df = pd.concat([player_df, final])
    player_df2=pd.concat((home,away))
    player_df2['Season']=season
    player_df2['League']=league
    player_df2['Description']=description
    player_df2['MatchDate']=date_str
    player_df2['MatchID']=k
    player_df3=pd.concat([player_df3,player_df2])
    total=total+['Season','League','Description','MatchDate','MatchID']
    print("All "+str(k)+"th match details obtained")
player_df.columns=total
print('Web Scraping - Completed')
# Out:
# C:
match details obtained
# Web Scrape - Get Player Performance Metrics per Match from Understat.com
# All 4756th match details obtained
# Web Scrape - Get Player Performance Metrics per Match from Understat.com
# All 4757th match details obtained
# Web Scraping - Completed

# %%
player_df.to_csv('player_data.csv')
player_df3.to_csv('player_datav2.csv')
player_df3.shape
# Out:
# (8745, 26)

# %% [markdown]
# ### C. Scrape EPL Scoreboard(League Table) Statistics for five seasons - 2014 to 2018

# %%
import requests, bs4, os
import json
import numpy as np
import pandas as pd
link ="https://understat.com/league/EPL/"
start=2014
end=2019
player_perf=pd.DataFrame()
final=pd.DataFrame()
for k in range(start,end):
    res = requests.get(link+str(k))
    res.raise_for_status()
    soup = bs4.BeautifulSoup(res.text)
    print('Web Scrape - Get Final Team and Player Scoreboard from Understat.com')
    ## Team Final Scoreboard JSON Data
    titles=soup.find('title')
    players = soup.find_all('script')
    v2=players[2].text.strip()
    v3 =v2.encode('utf8').decode('unicode_escape')
    c = v3.find("'")
    d =v3.find(");");
    #print(c)
    newstr = v3[c+1:d-1]
    #print(newstr)
    y = json.loads(newstr)
    f1 = list(y.keys())
    for i in range(0,len(f1)):
        for j in range(0,len(y[f1[i]]['history'])):
            home = pd.DataFrame.from_dict(y[f1[i]]['history'][j],orient='index').transpose()
            home.reset_index(inplace=True)
            home.drop(columns=['index'],inplace=True)
            home['id']=y[f1[i]]['id']
            home['team']=y[f1[i]]['title']
            home['season']=str(k)
            final=pd.concat([final,home])
    ## Player Scoreboard
    p2=players[3].text.strip()
    p3 =p2.encode('utf8').decode('unicode_escape')
    c1 = p3.find("'")
    d1 =p3.find(");");
    #print(c)
    newstr1 = p3[c1+1:d1-1]
    #print(newstr)
    player_y = json.loads(newstr1)
    player_perf=pd.DataFrame()
    for s in range(0,len(player_y)):
        players = pd.DataFrame.from_dict(player_y[s],orient='index').transpose()
        players.reset_index(inplace=True)
        players.drop(columns=['index'],inplace=True)
        players['season']=str(k)
        player_perf=pd.concat([player_perf,players])
    print("All "+str(k)+"th match details obtained")
team_brd=final[['id', 'season','team','h_a', 'xG', 'xGA', 'npxG', 'npxGA', 'ppda', 'ppda_allowed', 'deep',
       'deep_allowed', 'scored', 'missed', 'xpts', 'result', 'date', 'wins',
       'draws', 'loses', 'pts', 'npxGD']]
team_brd.set_index('id',inplace=True)
player_brd=player_perf[['id','season', 'player_name', 'games', 'time', 'goals', 'xG', 'assists', 'xA',
       'shots', 'key_passes', 'yellow_cards', 'red_cards', 'position',
       'team_title', 'npg', 'npxG', 'xGChain', 'xGBuildup']]
player_brd.set_index('id',inplace=True)
print('Web Scraping - Completed')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Web Scrape - Get Final Team and Player Scoreboard from Understat.com
# All 2014th match details obtained
# Web Scrape - Get Final Team and Player Scoreboard from Understat.com
# All 2015th match details obtained
# Web Scrape - Get Final Team and Player Scoreboard from Understat.com
# All 2016th match details obtained
# Web Scrape - Get Final Team and Player Scoreboard from Understat.com
# All 2017th match details obtained
# Web Scrape - Get Final Team and Player Scoreboard from Understat.com
# All 2018th match details obtained
# Web Scraping - Completed

# %%
player_brd.shape
# Out:
# (4227, 18)

# %%
player_brd.to_csv('player_performance.csv')

# %%
player_brd
# Out:
#      season player_name games time goals xG assists xA shots key_passes  \
# id
# 4536   2014        Nani     1   41     0  0       0  0     0          0
#
#      yellow_cards red_cards position         team_title npg npxG  \
# id
# 4536            0         0        S  Manchester United   0    0
#
#                   xGChain            xGBuildup
# id
# 4536  0.07314915955066681  0.07314915955066681

# %% [markdown]
# ### D. Scrape EPL Team Metric Statistics  for five seasons - 2014 to 2018
# Metrics like Attacking Play, Position in the Pitch, Formation used, Situational Play, Shots Timing etc.

# %% [markdown]
# Example Link : https://understat.com/team/Leicester/2015

# %%
import requests, bs4, os
import json
import numpy as np
import pandas as pd
scrape_link='https://understat.com/team/'
main_link ='https://understat.com/league/EPL/'
season=2018
res = requests.get(main_link+str(season))
res.raise_for_status()
soup = bs4.BeautifulSoup(res.text)
print('Web Scrape - Get Team Details from Understat.com')
## Team Final Scoreboard JSON Data
teams = soup.find_all('script')
t2=teams[2].text.strip()
t3 =t2.encode('utf8').decode('unicode_escape')
c = t3.find("'")
d =t3.find(");")
teamstr = t3[c+1:d-1]
x = json.loads(teamstr)
l=list(x.keys())
teams=[]
fsituation=pd.DataFrame()
fformation=pd.DataFrame()
fgamestate=pd.DataFrame()
ftiming=pd.DataFrame()
fshotzones=pd.DataFrame()
fattackspeed=pd.DataFrame()
fresult=pd.DataFrame()

for i in range(0,len(l)):
    c =(x[l[i]]['title'])
    d =c.replace(' ','_')
    #print(d)
    teams.append(d)
print('Team Details Extracted')
print("End of Web scraping")
for k in range(0,len(teams)):
    name=teams[k]
    res = requests.get(scrape_link+name+"/"+str(season))
    res.raise_for_status()
    soup = bs4.BeautifulSoup(res.text)
    print('Web Scrape - Get Team Metrics from Understat.com')
    ## Team Final Scoreboard JSON Data
    titles=soup.find('title')
    players = soup.find_all('script')
    v2=players[2].text.strip()
    v3 =v2.encode('utf8').decode('unicode_escape')
    c = v3.find("'")
    d =v3.find(");");
    #print(c)
    newstr = v3[c+1:d-1]
    #print(newstr)
    y = json.loads(newstr)
    print("Iteration "+str(k)+" Team Name "+name+" Data Length "+str(len(y)))
    f1 = list(y.keys())
    team=titles.text.split('|')[0].split(' ')[0]
    description=titles.text.split('|')[0]
    #season='2015'
    situation=pd.DataFrame()
    formation=pd.DataFrame()
    gamestate=pd.DataFrame()
    timing=pd.DataFrame()
    shotzones=pd.DataFrame()
    attackspeed=pd.DataFrame()
    result=pd.DataFrame()
    for i in range(0,len(f1)):
        if (f1[i]=='situation'):
            finaway=pd.DataFrame()
            home = pd.DataFrame.from_dict(y[f1[i]],orient='index')
            home.rename(columns=lambda x:x+'F',inplace=True)
            home.drop(columns='againstF',inplace=True)
            f2 = list(y[f1[i]].keys())
            for j in range(0,len(f2)):
                #print(y[f1[i]][f2[j]])
                against=pd.DataFrame.from_dict(y[f1[i]][f2[j]]['against'],orient='index').transpose()
                against['situation']=f2[j]
                finaway=pd.concat([finaway,against])
            finaway.set_index('situation',inplace=True)
            finaway.rename(columns=lambda x:x+'A',inplace=True)
            situation=pd.concat([home,finaway],axis=1, join='inner')
            situation['xGD']=situation['xGF']-situation['xGA']
            situation['xGF/Sh']=situation['xGF']/situation['shotsF']
            situation['xGA/Sh']=situation['xGA']/situation['shotsA']
            situation['team']=teams[k]
            situation['description']=description
            situation['situation']=situation.index
            situation['season']=season
            situation=situation[['season','team', 'description', 'situation','shotsF', 'goalsF', 'xGF', 'shotsA', 'goalsA', 'xGA', 'xGD', 'xGF/Sh',
           'xGA/Sh']]
            situation.reset_index(inplace=True)
        if (f1[i]=='formation'):
            finaway=pd.DataFrame()
            home = pd.DataFrame.from_dict(y[f1[i]],orient='index')
            home.rename(columns=lambda x:x+'F',inplace=True)
            home.drop(columns='againstF',inplace=True)
            f2 = list(y[f1[i]].keys())
            for j in range(0,len(f2)):
               # print(y[f1[i]][f2[j]])
                against=pd.DataFrame.from_dict(y[f1[i]][f2[j]]['against'],orient='index').transpose()
                against['formation']=f2[j]
                finaway=pd.concat([finaway,against])
            finaway.set_index('formation',inplace=True)
            finaway.rename(columns=lambda x:x+'A',inplace=True)
            formation=pd.concat([home,finaway],axis=1, join='inner')
            formation['xGD']=formation['xGF']-formation['xGA']
            formation['xGF90']=formation['xGF']/(formation['timeF']/90)
            formation['xGA90']=formation['xGA']/(formation['timeF']/90)
            formation['team']=teams[k]
            formation['description']=description
            formation['formation']=formation.index
            formation['season']=season
            formation=formation[['season','team', 'description','formation',  'statF', 'timeF', 'shotsF', 'goalsF', 'xGF', 'shotsA','goalsA', 'xGA', 'xGD', 'xGF90', 'xGA90']]
           # formation.reset_index(inplace=True)
        if (f1[i]=='gameState'):
            finaway=pd.DataFrame()
            home = pd.DataFrame.from_dict(y[f1[i]],orient='index')
            home.rename(columns=lambda x:x+'F',inplace=True)
            home.drop(columns='againstF',inplace=True)
            f2 = list(y[f1[i]].keys())
            for j in range(0,len(f2)):
               #print(y[f1[i]][f2[j]])
                against=pd.DataFrame.from_dict(y[f1[i]][f2[j]]['against'],orient='index').transpose()
                against['gameState']=f2[j]
                finaway=pd.concat([finaway,against])
            finaway.set_index('gameState',inplace=True)
            finaway.rename(columns=lambda x:x+'A',inplace=True)
            gamestate=pd.concat([home,finaway],axis=1, join='inner')
            gamestate['xGD']=gamestate['xGF']-gamestate['xGA']
            gamestate['xGF90']=gamestate['xGF']/(gamestate['timeF']/90)
            gamestate['xGA90']=gamestate['xGA']/(gamestate['timeF']/90)
            gamestate['team']=teams[k]
            gamestate['description']=description
            gamestate['gamestate']=gamestate.index
            gamestate['season']=season
            gamestate=gamestate[['season','team', 'description','gamestate',  'statF', 'timeF', 'shotsF', 'goalsF', 'xGF', 'shotsA','goalsA', 'xGA', 'xGD', 'xGF90', 'xGA90']]
            gamestate.reset_index(inplace=True)
        if (f1[i]=='timing'):
            finaway=pd.DataFrame()
            home = pd.DataFrame.from_dict(y[f1[i]],orient='index')
            home.rename(columns=lambda x:x+'F',inplace=True)
            home.drop(columns='againstF',inplace=True)
            f2 = list(y[f1[i]].keys())
            for j in range(0,len(f2)):
                #print(y[f1[i]][f2[j]])
                against=pd.DataFrame.from_dict(y[f1[i]][f2[j]]['against'],orient='index').transpose()
                against['timing']=f2[j]
                finaway=pd.concat([finaway,against])
            finaway.set_index('timing',inplace=True)
            finaway.rename(columns=lambda x:x+'A',inplace=True)
            timing=pd.concat([home,finaway],axis=1, join='inner')
            timing['xGD']=timing['xGF']-timing['xGA']
            timing['xGF/Sh']=timing['xGF']/timing['shotsF']
            timing['xGA/Sh']=timing['xGA']/timing['shotsA']
            timing['team']=teams[k]
            timing['description']=description
            timing['timing']=timing.index
            timing['season']=season
            timing=timing[['season','team', 'description', 'timing','shotsF', 'goalsF', 'xGF', 'shotsA', 'goalsA', 'xGA', 'xGD', 'xGF/Sh','xGA/Sh']]
        if (f1[i]=='shotZone'):
            finaway=pd.DataFrame()
            home = pd.DataFrame.from_dict(y[f1[i]],orient='index')
            home.rename(columns=lambda x:x+'F',inplace=True)
            home.drop(columns='againstF',inplace=True)
            f2 = list(y[f1[i]].keys())
            for j in range(0,len(f2)):
                #print(y[f1[i]][f2[j]])
                against=pd.DataFrame.from_dict(y[f1[i]][f2[j]]['against'],orient='index').transpose()
                against['shotzones']=f2[j]
                finaway=pd.concat([finaway,against])
            finaway.set_index('shotzones',inplace=True)
            finaway.rename(columns=lambda x:x+'A',inplace=True)
            shotzones=pd.concat([home,finaway],axis=1, join='inner')
            shotzones['xGD']=shotzones['xGF']-shotzones['xGA']
            shotzones['xGF/Sh']=shotzones['xGF']/shotzones['shotsF']
            shotzones['xGA/Sh']=shotzones['xGA']/shotzones['shotsA']
            shotzones['team']=teams[k]
            shotzones['description']=description
            shotzones['shotzones']=shotzones.index
            shotzones['season']=season
            shotzones=shotzones[['season','team', 'description', 'shotzones', 'statF', 'shotsF', 'goalsF', 'xGF', 'shotsA', 'goalsA', 'xGA', 'xGD','xGF/Sh', 'xGA/Sh']]
           # shotzones.reset_index(inplace=True)
        if (f1[i]=='attackSpeed'):
            finaway=pd.DataFrame()
            home = pd.DataFrame.from_dict(y[f1[i]],orient='index')
            home.rename(columns=lambda x:x+'F',inplace=True)
            home.drop(columns='againstF',inplace=True)
            f2 = list(y[f1[i]].keys())
            for j in range(0,len(f2)):
                #print(y[f1[i]][f2[j]])
                against=pd.DataFrame.from_dict(y[f1[i]][f2[j]]['against'],orient='index').transpose()
                against['attackspeed']=f2[j]
                finaway=pd.concat([finaway,against])
            finaway.set_index('attackspeed',inplace=True)
            finaway.rename(columns=lambda x:x+'A',inplace=True)
            attackspeed=pd.concat([home,finaway],axis=1, join='inner')
            attackspeed['xGD']=attackspeed['xGF']-attackspeed['xGA']
            attackspeed['xGF/Sh']=attackspeed['xGF']/attackspeed['shotsF']
            attackspeed['xGA/Sh']=attackspeed['xGA']/attackspeed['shotsA']
            attackspeed['team']=teams[k]
            attackspeed['description']=description
            attackspeed['attackspeed']=attackspeed.index
            attackspeed['season']=season
            attackspeed=attackspeed[['season','team', 'description', 'attackspeed', 'statF', 'shotsF', 'goalsF', 'xGF', 'shotsA', 'goalsA', 'xGA', 'xGD','xGF/Sh', 'xGA/Sh']]
            attackspeed.reset_index(inplace=True)
        if (f1[i]=='result'):
            finaway=pd.DataFrame()
            home = pd.DataFrame.from_dict(y[f1[i]],orient='index')
            home.rename(columns=lambda x:x+'F',inplace=True)
            home.drop(columns='againstF',inplace=True)
            f2 = list(y[f1[i]].keys())
            for j in range(0,len(f2)):
                #print(y[f1[i]][f2[j]])
                against=pd.DataFrame.from_dict(y[f1[i]][f2[j]]['against'],orient='index').transpose()
                against['result']=f2[j]
                finaway=pd.concat([finaway,against])
            finaway.set_index('result',inplace=True)
            finaway.rename(columns=lambda x:x+'A',inplace=True)
            result=pd.concat([home,finaway],axis=1, join='inner')
            result['xGD']=result['xGF']-result['xGA']
            result['xGF/Sh']=result['xGF']/result['shotsF']
            result['xGA/Sh']=result['xGA']/result['shotsA']
            result['team']=teams[k]
            result['description']=description
            result['result']=result.index
            result['season']=season
            result=result[['season','team', 'description', 'result', 'shotsF', 'goalsF', 'xGF', 'shotsA', 'goalsA', 'xGA', 'xGD', 'xGF/Sh','xGA/Sh']]
           # result.reset_index(inplace=True)
    fsituation=pd.concat([fsituation,situation])
    fformation=pd.concat([fformation,formation])
    fgamestate=pd.concat([fgamestate,gamestate])
    ftiming=pd.concat([ftiming,timing])
    fshotzones=pd.concat([fshotzones,shotzones])
    fattackspeed=pd.concat([fattackspeed,attackspeed])
    fresult=pd.concat([fresult,result])
print("Web scraping for "+str(season)+" completed")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Web Scrape - Get Team Details from Understat.com
# Team Details Extracted
# End of Web scraping
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 0 Team Name Everton Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 1 Team Name Bournemouth Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 2 Team Name Southampton Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 3 Team Name Leicester Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 4 Team Name Crystal_Palace Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 5 Team Name Chelsea Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 6 Team Name West_Ham Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 7 Team Name Tottenham Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 8 Team Name Arsenal Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 9 Team Name Newcastle_United Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 10 Team Name Liverpool Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 11 Team Name Manchester_City Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 12 Team Name Manchester_United Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 13 Team Name Watford Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 14 Team Name Burnley Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 15 Team Name Huddersfield Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 16 Team Name Brighton Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 17 Team Name Cardiff Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 18 Team Name Fulham Data Length 7
# Web Scrape - Get Team Metrics from Understat.com
# Iteration 19 Team Name Wolverhampton_Wanderers Data Length 7
# Web scraping for 2018 completed

# %% [markdown]
# #### Check if all the seven dataset scraped from Understat have 20 teams in each run

# %%
if (len(fsituation.team.unique())==20):
    print("Pass - Situation")
else:
    print("Fail - Situation")
if (len(fformation.team.unique())==20):
    print("Pass - Formation")
else:
    print("Fail - Formation")
if (len(fgamestate.team.unique())==20):
    print("Pass - Gamestate")
else:
    print("Fail - Gamestate")
if (len(ftiming.team.unique())==20):
    print("Pass - Timing")
else:
    print("Fail - Timing")
if (len(fshotzones.team.unique())==20):
    print("Pass - Shotzones")
else:
    print("Fail - Shotzones")
if (len(fattackspeed.team.unique())==20):
    print("Pass - Attackspeed")
else:
    print("Fail - Attackspeed")
if (len(fresult.team.unique())==20):
    print("Pass - Result")
else:
    print("Fail - Result")
# Out:
# Pass - Situation
# Pass - Formation
# Pass - Gamestate
# Pass - Timing
# Pass - Shotzones
# Pass - Attackspeed
# Pass - Result

# %% [markdown]
# #### Export as csv for data engineering and EDA

# %%
fsituation.to_csv('situation.csv')
fformation.to_csv('formation.csv')
fgamestate.to_csv('gamestate.csv')
ftiming.to_csv('timing.csv')
fshotzones.to_csv('shotzones.csv')
fattackspeed.to_csv('attackspeed.csv')
fresult.to_csv('result.csv')

# %%
len(fsituation.team.unique())
# Out:
# array(['Aston_Villa', 'Everton', 'Bournemouth', 'Southampton',
#        'Leicester', 'West_Bromwich_Albion', 'Sunderland',
#        'Crystal_Palace', 'Norwich', 'Chelsea', 'West_Ham', 'Tottenham',
#        'Arsenal', 'Swansea', 'Stoke', 'Newcastle_United', 'Liverpool',
#        'Manchester_City', 'Manchester_United', 'Watford'], dtype=object)
